# %% [markdown]
# # 1º Trabalho Prático: Exploração de Ambiente Simulado com Robô Móvel

# %% [markdown]
# ## Introdução
# Este trabalho descreve a implementação de um sistema de exploração de ambiente com um robô móvel, utilizando a plataforma CoppeliaSim. O objetivo é representar o ambiente e seus elementos a partir de diferentes referenciais, através de sistemas de coordenadas, matrizes de transformação e mapeamento por laser. As células de código deste trabalho devem ser executadas em ordem.

# %% [markdown]
# ## Etapas

# %% [markdown]
# #### 1ª Etapa:
# Para iniciar o trabalho, foi criada uma nova cena no CoppeliaSim, contendo um robô móvel (Pioneer 3DX) e seis elementos adicionais. Além destes, optei por colocar uma parede externa contornando a cena para impedir que o robô caia ao se locomover.
# <br><br><center><img src="Cena_Inicial_Coppelia.png" style="width: 700px"></center>

# %% [markdown]
# #### 2ª Etapa:
# Na segunda etapa do trabalho, sistemas de coordenadas foram afixados a todos os objetos da cena e um diagrama com o posicionamento dos elementos e as transformações de referencial entre eles foi criado, como pode ser observado abaixo:
# <br><br><center><img src="Diagrama_Posicao.png" style="width: 500px"></center>

# %% [markdown]
# #### Importação de Bibliotecas e Implementação de Funções:

# %%
from coppeliasim_zmqremoteapi_client import RemoteAPIClient
import time
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Funções que executam operações com matrizes de rotação e transformação de coordenadas em relação a um referencial:

# %%
def rotation_z (theta):
    return np.array ([[ np.cos(theta) , -np.sin(theta) , 0 ],
                      [ np.sin(theta) ,  np.cos(theta) , 0 ],
                      [ 0             ,  0             , 1 ]])
  
def rotation_y (theta):
    return np.array ([[  np.cos(theta) , 0 , np.sin(theta) ],
                      [  0             , 1 , 0             ],
                      [ -np.sin(theta) , 0 , np.cos(theta) ]])

def rotation_x (theta):
    return np.array ([[ 1 , 0             ,  0             ],
                      [ 0 , np.cos(theta) , -np.sin(theta) ],
                      [ 0 , np.sin(theta) ,  np.cos(theta) ]])

def rotation_matrix (alpha, beta, gamma):
    
    return rotation_z (alpha) @ rotation_y (beta) @ rotation_x (gamma)

def homogeneous_transformation_matrix (rotation_matrix, translation_vector):
    
    matrix = np.column_stack ((rotation_matrix, translation_vector[:3]))
    matrix = np.row_stack ((matrix, [0, 0, 0, 1]))
    return matrix

def reverse_transformation (a_to_b_orientation, a_to_b_position):
    
    b_to_a_rotation = np.transpose (rotation_matrix (*np.flip (a_to_b_orientation)))
    b_to_a_position = -1 * b_to_a_rotation @ a_to_b_position[:3]
    return homogeneous_transformation_matrix (b_to_a_rotation, b_to_a_position)

def composite_transformation (a_to_b_rotation, a_to_b_position, b_to_c_rotation, b_to_c_position):
    
    a_to_c_rotation = b_to_c_rotation @ a_to_b_rotation
    a_to_c_position = homogeneous_transformation_matrix (b_to_c_rotation, b_to_c_position) @ a_to_b_position
    return homogeneous_transformation_matrix (a_to_c_rotation, a_to_c_position)

def to_world_transformation_matrix (c_object):
    
    object_to_world_rotation = rotation_matrix (*np.flip (c_object.global_orientation))
    return homogeneous_transformation_matrix (object_to_world_rotation, c_object.global_position)

def to_robot_transformation_matrix (c_object, robot):
    
    world_to_robot_rotation = np.transpose (rotation_matrix (*np.flip (robot.global_orientation)))
    world_to_robot_position = -1 * world_to_robot_rotation @ robot.global_position[:3]

    object_to_world_rotation =  rotation_matrix (*np.flip (c_object.global_orientation))
    return composite_transformation (object_to_world_rotation, c_object.global_position, world_to_robot_rotation, world_to_robot_position)

# %% [markdown]
# ##### Funções para transformação de conjuntos de dados:

# %%
# Retorna os posicionamentos e orientações de uma lista de objetos em relação a um referencial
# Também imprime a matriz de transformação homogênia de coordenadas globais para relativas
def calc_relative_location (objects, referential):
    
    world_to_referential_transformation = reverse_transformation (referential.global_orientation, referential.global_position)
    print (world_to_referential_transformation)
    
    objects_to_referential_position = []
    objects_to_referential_orientation = []
    
    for obj in objects:
        objects_to_referential_position.append (world_to_referential_transformation @ obj.global_position)
        objects_to_referential_orientation.append (np.subtract (obj.global_orientation, referential.global_orientation))

    return objects_to_referential_position, objects_to_referential_orientation

# Substitui a representação de um ponto [angulo, distancia] no referencial do laser para a representação em coordenadas (+ escala) no referencial global
def transform_laser_data (laser_data, laser_to_world_transformation):
    
    obstacles_list = []
    for ang, dist in laser_data:
        # Quando o feixe não acerta nada, retorna o valor máximo (5)
        if dist <= 4.9:
            x = dist * np.cos (ang)
            y = dist * np.sin (ang)
            c = 1 if ang < 0 else 0
            obstacles_list.append (np.append (laser_to_world_transformation @ [x, y, 0, 1], [c])) 
    return obstacles_list

# %% [markdown]
# ##### Funções relativas a movimentação do robô:

# %%
# Modelo cinemático
def cinematic_model (v, w, L, r):
    
    wl = v / r - (w * L) / (2 * r)
    wr = v / r + (w * L) / (2 * r)
    return [wl, wr]

# Escolhe qual o próximo movimento do robô de acordo com a leitura do laser e define a velocidade linear e angular necessária para tal
def choose_robot_movement (laser_data):
    
    linear_velocity = 0
    angular_velocity = np.deg2rad (0)      

    frente = int (len (laser_data) / 2)
    lado_direito = int (len (laser_data) * 1 / 4)
    lado_esquerdo = int (len (laser_data) * 3 / 4)
    
    if laser_data[frente, 1] > 2:
        linear_velocity = .5
        angular_velocity = 0
    elif laser_data[lado_direito, 1] > 2:
        linear_velocity = 0
        angular_velocity = np.deg2rad (-30)
    elif laser_data[lado_esquerdo, 1] > 2:
        linear_velocity = 0
        angular_velocity = np.deg2rad (30)
        
    return [linear_velocity, angular_velocity]

def explore_world (robot, laser, laser_to_robot_transformation, exploration_time):
    
    t = 0
    startTime = time.time()
    lastTime = startTime

    robot_path = []
    transformed_laser_data = []

    while t < exploration_time:

        #Calcula o tempo decorrido desde a última atualização
        now = time.time()
        dt = now - lastTime
    
        robot.update_location ()
        robot_path.append (robot.global_position)

        # Realiza a transformação de leituras do laser para coordenadas no referencial global
        robot_to_world_transformation = to_world_transformation_matrix (robot)
        laser_to_world_transformation = robot_to_world_transformation @ laser_to_robot_transformation
        laser_data = read_sensor_data (laser.range_data, laser.angle_data)
        transformed_laser_data.append (transform_laser_data (laser_data, laser_to_world_transformation))
        
        # Escolhe a velocidade do robô com base nos dados do sensor laser
        robot_velocity = choose_robot_movement (laser_data)
        # Define a velocidade das rodas de acordo com o modelo cinemático
        wheel_velocity = cinematic_model (*robot_velocity, robot.length, robot.wheel_radius)
        set_wheel_velocity (robot.l_wheel, robot.r_wheel, *wheel_velocity)  
        
        # Atualiza o tempo total de exploração 
        t = t + dt  
        lastTime = now
  
    set_wheel_velocity (robot.l_wheel, robot.r_wheel, 0, 0)

    return robot_path, transformed_laser_data

# %% [markdown]
# ##### Funções relacionadas à visualização e plotagem de sistemas de coordenadas, leituras de laser e trajetórias:

# %%
def configure_print_options ():
    np.set_printoptions (suppress = True, precision = 6)

def plot_frame (origin, rotation_matrix, c = ['r', 'g']):
    
    axis_size = 1.0    
    axes = axis_size * rotation_matrix
        
    x_axis = np.array (axes[0:2, 0])
    plt.quiver (*origin[:2], *x_axis, color=c[0], angles='xy', scale_units='xy', scale=1)
    y_axis = np.array (axes[0:2, 1])
    plt.quiver (*origin[:2], *y_axis, color=c[1], angles='xy', scale_units='xy', scale=1)

# Plota o sistema de coordenadas de cada objeto no referencial global
def plot_objects_frames (objects):
    
    plt.figure (figsize = (6,6), dpi = 100)
    
    for i in range (len (objects)):
        plot_frame (objects[i].global_position[:2], rotation_z (objects[i].global_orientation[2]))
    plot_frame (robot.global_position[:2], rotation_z (robot.global_orientation[2]), ['b', 'b'])
    
    plt.axis ('scaled')
    plt.axis ((-5, 5, -5, 5))

# Plota o sistema de coordenadas de cada objeto no referencial do robô
def plot_objects_frames_by_robot (coppelia_objects, robot):

    objects_position, objects_orientation = calc_relative_location (coppelia_objects, robot)
    
    plt.figure (figsize = (6,6), dpi = 100)
    
    for i in range (len(objects_position)):
        plt.quiver (*[0,0], *objects_position[i][:2], color = 'k', angles = 'xy', scale_units = 'xy', scale = 1)
        plot_frame (objects_position[i][:2], rotation_matrix (*np.flip (objects_orientation[i])))
    plot_frame ([0,0], rotation_z (0), ['b', 'b'])
    
    plt.axis ('scaled')
    plt.axis ((-5, 5, -5, 5))

def draw_laser_scan (laser_data, transformation_matrix, robot, max_sensor_range=5):
    
    fig = plt.figure (figsize = (6,6), dpi = 100)
    ax = fig.add_subplot (111, aspect='equal')

    transformed_laser_data = transform_laser_data (laser_data, transformation_matrix)
    for coord in transformed_laser_data:
        c = 'r' if coord[4] else 'b'
        ax.plot (*coord[:2], 'o', color=c)

    ax.plot (*robot.global_position[:2], 'ko', markersize=10)
        
    ax.grid ()
    ax.set_xlim ([-max_sensor_range, max_sensor_range])
    ax.set_ylim ([-max_sensor_range, max_sensor_range])

def plot_world_by_laser (robot, laser_range_data, laser_angle_data, laser_to_robot_transformation):
    
    robot_to_world_transformation = to_world_transformation_matrix (robot)
    laser_data = read_sensor_data (laser_range_data, laser_angle_data)

    print (robot_to_world_transformation)
    draw_laser_scan (laser_data, robot_to_world_transformation @ laser_to_robot_transformation, robot, 3)
    
def plot_world_by_moving_robot (robot_path, laser_data):
    
    fig = plt.figure (figsize = (6,6), dpi = 100)
    ax = fig.add_subplot (111, aspect='equal')
    
    for i in range (len (laser_data)):
        for j in range (len (laser_data[i])):
            coord = laser_data[i][j]
            ax.plot (*coord[:2], 'ro', markersize=5)

    for coord in robot_path:
        ax.plot (*coord[:2], 'k.', markersize=5)
    
    ax.grid ()
    ax.set_xlim ([-3, 3])
    ax.set_ylim ([-3, 3])

# %% [markdown]
# ##### Classe de elementos do CoppeliaSim e funções de manipulação da simulação:
# Optei por utilizar uma classe para armazenar os dados de cada objeto da cena, mantendo a organização e legibilidade do código, bem como evitando os custos de chamadas constantes a RemoteAPI.

# %%
client = RemoteAPIClient ()
sim = client.require ('sim')

class CoppeliaObject:
    
    def __init__ (self, name):
        self.name = name
        self.handle = sim.getObject (name)
        self.global_position = sim.getObjectPosition (self.handle) + [1]
        self.global_orientation = sim.getObjectOrientation (self.handle)
    def new_location (self, position, orientation):
        sim.setObjectPosition (self.handle, position)
        sim.setObjectOrientation (self.handle, orientation)
        self.global_position = position + [1]
        self.global_orientation = orientation
    def update_location (self):
        self.global_position = sim.getObjectPosition (self.handle)
        self.global_orientation = sim.getObjectOrientation (self.handle)

def read_sensor_data (range_data_signal_id="hokuyo_range_data", angle_data_signal_id="hokuyo_angle_data"):
    
    while sim.getStringSignal (range_data_signal_id) == None:
       continue
        
    string_range_data = sim.getStringSignal (range_data_signal_id)
    string_angle_data = sim.getStringSignal (angle_data_signal_id)

    raw_range_data = sim.unpackFloatTable (string_range_data)
    raw_angle_data = sim.unpackFloatTable (string_angle_data)

    return np.array ([raw_angle_data, raw_range_data]).T
    
def set_wheel_velocity (left_wheel, right_wheel, left_velocity, right_velocity):
    
    sim.setJointTargetVelocity (left_wheel, left_velocity)
    sim.setJointTargetVelocity (right_wheel, right_velocity)

# %% [markdown]
# #### 3ª Etapa:
# A matriz de transformação homogênea que representa as posições dos outros elementos da cena no referencial local do robô foi calculada. Optei por criar uma lista dos objetos adicionais na cena para facilitar a passagem como parâmetro. Outra decisão importante tomada no decorrer do projeto foi a de utilizar várias cenas para etapas diferentes do trabalho, visto que foi necessário realizar alterações nas cenas que poderiam comprometer a execução do código de etapas anteriores.

# %%
sim.setStepping (True)
sim.loadScene ("C:/Users/tatia/Desktop/UFMG/RM/TP1/TP1_2.ttt")
sim.startSimulation ()

bill = CoppeliaObject ("/Bill")
chair = CoppeliaObject ("/swivelChair")
cupboard = CoppeliaObject ("/cupboard")
division = CoppeliaObject ("/20cmHighWall100cm")
plant = CoppeliaObject ("/indoorPlant")
robot = CoppeliaObject ("/PioneerP3DX")
table = CoppeliaObject ("/customizableTable")

coppelia_objects = (bill, chair, cupboard, division, plant, table)

configure_print_options ()

plot_objects_frames (coppelia_objects)
print ("Matrizes de trasformação homogêneas: Robô -> Mundo")
plot_objects_frames_by_robot (coppelia_objects, robot)
# Out:
# Matrizes de trasformação homogêneas: Robô -> Mundo
# [[-1.       -0.        0.       -0.394472]
#  [ 0.       -1.        0.       -2.174999]
#  [ 0.        0.        1.       -0.138793]
#  [ 0.        0.        0.        1.      ]]

# %% [markdown]
# #### 4ª Etapa:
# O robô foi colocado em outras três posições diferentes da cena, variando também a orientação em relação aos elementos. Para cada posição e orientação, os referenciais e relacionamentos foram plotados novamente, como pode se observar ao rodar o código abaixo.

# %%
print ("Matrizes de trasformação homogêneas: Robô -> Mundo")
robot.new_location ([1.0, 1.2, robot.global_position[2]], [0,0,np.deg2rad(-130)])
plot_objects_frames_by_robot (coppelia_objects, robot)
robot.new_location ([1.5, -0.4, robot.global_position[2]], [0,0,np.deg2rad(90)])
plot_objects_frames_by_robot (coppelia_objects, robot)
robot.new_location ([-1.65, 1.7, robot.global_position[2]], [0,0,np.deg2rad(-30)])
plot_objects_frames_by_robot (coppelia_objects, robot)

sim.stopSimulation()
time.sleep(5)
# Out:
# Matrizes de trasformação homogêneas: Robô -> Mundo
# [[-0.642788 -0.766044  0.        1.562041]
#  [ 0.766044 -0.642788  0.        0.005301]
#  [ 0.        0.        1.       -0.138793]
#  [ 0.        0.        0.        1.      ]]
# [[ 0.        1.        0.        0.4     ]
#  [-1.        0.        0.        1.5     ]
#  [ 0.        0.        1.       -0.138793]
#  [ 0.        0.        0.        1.      ]]
# [[ 0.866025 -0.5       0.        2.278942]
#  [ 0.5       0.866025  0.       -0.647243]
#  [ 0.        0.        1.       -0.138793]
#  [ 0.        0.        0.        1.      ]]

# %% [markdown]
# #### 5ª Etapa:
# O robô inicialmente adicionado na cena foi substituído pelo robô com laser visto em aula. Foram definidas as matrizes de transformações $^{R}_{L}T$ (laser → robô) e $^{W}_{R}T$ (robô → mundo), e os pontos das leituras do laser, realizadas a partir de quatro posições diferentes, foram plotados no referencial global.

# %%
sim.loadScene ("C:/Users/tatia/Desktop/UFMG/RM/TP1/TP1_5.ttt")
sim.startSimulation ()

new_robot = CoppeliaObject ("/Pioneer_p3dx")
laser = CoppeliaObject ("/fastHokuyo")

laser.range_data = "hokuyo_range_data"
laser.angle_data = "hokuyo_angle_data"

laser_to_robot_transformation = to_robot_transformation_matrix (laser, new_robot)
print ("Matriz de trasformação homogênea: Laser -> Robô")
print (laser_to_robot_transformation)

print ("Matrizes de trasformação homogêneas: Robô -> Mundo")
plot_world_by_laser (new_robot, laser.range_data, laser.angle_data, laser_to_robot_transformation)
new_robot.new_location ([1.0, 1.2, robot.global_position[2]], [0,0,np.deg2rad(-130)])
time.sleep(1)
plot_world_by_laser (new_robot, laser.range_data, laser.angle_data, laser_to_robot_transformation)
new_robot.new_location ([1.5, -0.4, robot.global_position[2]], [0,0,np.deg2rad(90)])
time.sleep(1)
plot_world_by_laser (new_robot, laser.range_data, laser.angle_data, laser_to_robot_transformation)
new_robot.new_location ([-1.65, 1.7, robot.global_position[2]], [0,0,np.deg2rad(-30)])
time.sleep(1)
plot_world_by_laser (new_robot, laser.range_data, laser.angle_data, laser_to_robot_transformation)

sim.stopSimulation ()
time.sleep (5)
# Out:
# Matriz de trasformação homogênea: Laser -> Robô
# [[ 1.        0.000011  0.000149 -0.00103 ]
#  [-0.000011  1.        0.000027  0.00002 ]
#  [-0.000149 -0.000027  1.        0.149995]
#  [ 0.        0.        0.        1.      ]]
# Matrizes de trasformação homogêneas: Robô -> Mundo
# [[-0.999995  0.000003 -0.00312  -0.394081]
#  [-0.000003 -1.        0.000097 -2.175006]
#  [-0.00312   0.000097  0.999995  0.138635]
#  [ 0.        0.        0.        1.      ]]
# [[-0.642788  0.766044  0.        1.      ]
#  [-0.766044 -0.642788  0.        1.2     ]
#  [ 0.        0.        1.        0.138793]
#  [ 0.        0.        0.        1.      ]]
# [[ 0.       -1.        0.        1.5     ]
#  [ 1.        0.        0.       -0.4     ]
#  [ 0.        0.        1.        0.138793]
#  [ 0.        0.        0.        1.      ]]
# [[ 0.866025  0.5       0.       -1.65    ]
#  [-0.5       0.866025  0.        1.7     ]
#  [ 0.        0.        1.        0.138793]
# ...

# %% [markdown]
# #### 6ª Etapa:
# Um plot incremental foi criado para mostrar o caminho executado pelo robô ao longo da navegação, combinando todas as leituras de laser realizadas ao longo do trajeto. Essas informações foram representadas em um único gráfico considerando o referencial global. Optei por colocar as informações adicionais como atributos do robô para facilitar a passagem como parâmetro.

# %%
sim.loadScene("C:/Users/tatia/Desktop/UFMG/RM/TP1/TP1_6.ttt")
sim.startSimulation()

new_robot.length = 0.381
new_robot.wheel_radius = 0.0975
new_robot.l_wheel = sim.getObjectHandle (new_robot.name + '_leftMotor')
new_robot.r_wheel = sim.getObjectHandle (new_robot.name + '_rightMotor')

robot_path, laser_data = explore_world (new_robot, laser, laser_to_robot_transformation, 30)
plot_world_by_moving_robot (robot_path, laser_data)

sim.stopSimulation()

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Em conclusão, este trabalho foi fundamental para meu aprendizado em programação utilizando Python e para minha familiarização com a plataforma CoppeliaSim no contexto da robótica móvel. Através dele, pude compreender e aplicar conceitos importantes de transformações entre referenciais, essenciais para representar e navegar em ambientes complexos. Embora tenha enfrentado desafios na manutenção da integridade de um único código para todas as fases do projeto, essas dificuldades me incentivaram a buscar soluções criativas e aprimorar minha habilidade de desenvolvimento de software.
